# %%
from TrafficLight import SimpleTrafficLight, MemoryLessTrafficLight, MemoryLessTrafficLightMirror
import Model1
import Model2
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import HTML

# %% [markdown]
# **Traffic Lights**

# %%
simple_ew11 = SimpleTrafficLight()
simple_ew11.initialize(period=60, time_delay=0)

simple_ns11 = SimpleTrafficLight()
simple_ns11.initialize(period=60, time_delay=30)

simple_ew12 = SimpleTrafficLight()
simple_ew12.initialize(period=60, time_delay=10)

simple_ns12 = SimpleTrafficLight()
simple_ns12.initialize(period=60, time_delay=40)

simple_ew13 = SimpleTrafficLight()
simple_ew13.initialize(period=60, time_delay=5)

simple_ns13 = SimpleTrafficLight()
simple_ns13.initialize(period=60, time_delay=35)

simple_ew21 = SimpleTrafficLight()
simple_ew21.initialize(period=60, time_delay=15)

simple_ns21 = SimpleTrafficLight()
simple_ns21.initialize(period=60, time_delay=45)

simple_ew22 = SimpleTrafficLight()
simple_ew22.initialize(period=60, time_delay=40)

simple_ns22 = SimpleTrafficLight()
simple_ns22.initialize(period=60, time_delay=10)

simple_ew23 = SimpleTrafficLight()
simple_ew23.initialize(period=60, time_delay=50)

simple_ns23 = SimpleTrafficLight()
simple_ns23.initialize(period=60, time_delay=20)

simple_ew31 = SimpleTrafficLight()
simple_ew31.initialize(period=60, time_delay=25)

simple_ns31 = SimpleTrafficLight()
simple_ns31.initialize(period=60, time_delay=55)

simple_ew32 = SimpleTrafficLight()
simple_ew32.initialize(period=60, time_delay=10)

simple_ns32 = SimpleTrafficLight()
simple_ns32.initialize(period=60, time_delay=40)

simple_ew33 = SimpleTrafficLight()
simple_ew33.initialize(period=60, time_delay=0)

simple_ns33 = SimpleTrafficLight()
simple_ns33.initialize(period=60, time_delay=30)

# %%
memoryless_ew11 = MemoryLessTrafficLight()
memoryless_ew11.initialize(green_to_red_rate=1/60, red_to_green_rate=1/60)

memoryless_ns11 = MemoryLessTrafficLightMirror()
memoryless_ns11.initialize(traffic_light=memoryless_ew11)

memoryless_ew12 = MemoryLessTrafficLight()
memoryless_ew12.initialize(green_to_red_rate=1/60, red_to_green_rate=1/60)

memoryless_ns12 = MemoryLessTrafficLightMirror()
memoryless_ns12.initialize(traffic_light=memoryless_ew12)

memoryless_ew13 = MemoryLessTrafficLight()
memoryless_ew13.initialize(green_to_red_rate=1/60, red_to_green_rate=1/60)

memoryless_ns13 = MemoryLessTrafficLightMirror()
memoryless_ns13.initialize(traffic_light=memoryless_ew13)

memoryless_ew21 = MemoryLessTrafficLight()
memoryless_ew21.initialize(green_to_red_rate=1/60, red_to_green_rate=1/60)

memoryless_ns21 = MemoryLessTrafficLightMirror()
memoryless_ns21.initialize(traffic_light=memoryless_ew21)

memoryless_ew22 = MemoryLessTrafficLight()
memoryless_ew22.initialize(green_to_red_rate=1/60, red_to_green_rate=1/60)

memoryless_ns22 = MemoryLessTrafficLightMirror()
memoryless_ns22.initialize(traffic_light=memoryless_ew22)

memoryless_ew23 = MemoryLessTrafficLight()
memoryless_ew23.initialize(green_to_red_rate=1/60, red_to_green_rate=1/60)

memoryless_ns23 = MemoryLessTrafficLightMirror()
memoryless_ns23.initialize(traffic_light=memoryless_ew23)

memoryless_ew31 = MemoryLessTrafficLight()
memoryless_ew31.initialize(green_to_red_rate=1/60, red_to_green_rate=1/60)

memoryless_ns31 = MemoryLessTrafficLightMirror()
memoryless_ns31.initialize(traffic_light=memoryless_ew31)

memoryless_ew32 = MemoryLessTrafficLight()
memoryless_ew32.initialize(green_to_red_rate=1/60, red_to_green_rate=1/60)

memoryless_ns32 = MemoryLessTrafficLightMirror()
memoryless_ns32.initialize(traffic_light=memoryless_ew32)

memoryless_ew33 = MemoryLessTrafficLight()
memoryless_ew33.initialize(green_to_red_rate=1/60, red_to_green_rate=1/60)

memoryless_ns33 = MemoryLessTrafficLightMirror()
memoryless_ns33.initialize(traffic_light=memoryless_ew33)

# %% [markdown]
# **Intersection network**
#
# *M/M/1 queue model*
#
# The following intersection network consists of two four-way intersections in a 1x2 grid, each 30 m wide and 250 m apart. Each vehicle moves 14 m/s (50.4 km/h) at full speed.

# %%
intersection_system_1 = Model1.IntersectionNetworkSimulator()
intersection_system_1.initialize(grid_dimensions=(3,3), grid_distance=250)

intersection_system_1.set_queue_rate_parameters(grid_ind=(0,0), avg_departure_time=1, avg_arrival_time_s=10, avg_arrival_time_e=10)
intersection_system_1.set_queue_rate_parameters(grid_ind=(0,1), avg_departure_time=1, avg_arrival_time_s=10)
intersection_system_1.set_queue_rate_parameters(grid_ind=(0,2), avg_departure_time=1, avg_arrival_time_s=10, avg_arrival_time_w=10)
intersection_system_1.set_queue_rate_parameters(grid_ind=(1,0), avg_departure_time=1, avg_arrival_time_e=10)
intersection_system_1.set_queue_rate_parameters(grid_ind=(1,1), avg_departure_time=1)
intersection_system_1.set_queue_rate_parameters(grid_ind=(1,2), avg_departure_time=1, avg_arrival_time_w=10)
intersection_system_1.set_queue_rate_parameters(grid_ind=(2,0), avg_departure_time=1, avg_arrival_time_n=10, avg_arrival_time_e=10)
intersection_system_1.set_queue_rate_parameters(grid_ind=(2,1), avg_departure_time=1, avg_arrival_time_n=10)
intersection_system_1.set_queue_rate_parameters(grid_ind=(2,2), avg_departure_time=1, avg_arrival_time_n=10, avg_arrival_time_w=10)

intersection_system_1.set_traffic_lights(grid_ind=(0,0), traffic_light_ns=simple_ns11, traffic_light_ew=simple_ew11)
intersection_system_1.set_traffic_lights(grid_ind=(0,1), traffic_light_ns=simple_ns12, traffic_light_ew=simple_ew12)
intersection_system_1.set_traffic_lights(grid_ind=(0,2), traffic_light_ns=simple_ns13, traffic_light_ew=simple_ew13)
intersection_system_1.set_traffic_lights(grid_ind=(1,0), traffic_light_ns=simple_ns21, traffic_light_ew=simple_ew21)
intersection_system_1.set_traffic_lights(grid_ind=(1,1), traffic_light_ns=simple_ns22, traffic_light_ew=simple_ew22)
intersection_system_1.set_traffic_lights(grid_ind=(1,2), traffic_light_ns=simple_ns23, traffic_light_ew=simple_ew23)
intersection_system_1.set_traffic_lights(grid_ind=(2,0), traffic_light_ns=simple_ns31, traffic_light_ew=simple_ew31)
intersection_system_1.set_traffic_lights(grid_ind=(2,1), traffic_light_ns=simple_ns32, traffic_light_ew=simple_ew32)
intersection_system_1.set_traffic_lights(grid_ind=(2,2), traffic_light_ns=simple_ns33, traffic_light_ew=simple_ew33)

# %%
intersection_system_1.set_observable_intersections(grid_inds=intersection_system_1.grid_inds)

# %%
intersection_system_1.simulate(delta_t=0.1, end_time=120, animate=True, fig_width=4, file_name="figs/simulation1_3x3.mp4", speed=3)

# %% [markdown]
# View the video below.

# %%
HTML("""
<div align="middle">
<video width="80%" controls>
      <source src="figs/simulation1_3x3.mp4" type="video/mp4">
</video></div>""")
# Out:
# <div align="middle">
# <video width="80%" controls>
#       <source src="figs/simulation1_3x3.mp4" type="video/mp4">
# </video></div>

# %%
fig, axs = intersection_system_1.plot_queue_stats(plt=plt, grid_ind=(0,1), direction='E', end_time=round(intersection_system_1.time), delta_t=0.1, traffic_light=simple_ew12,fig_size=(6,6))
plt.savefig('figs/3x3_eastbound_(0,1)_1', bbox_inches='tight')

# %% [markdown]
# *Single queue with on/off memoryless service*

# %%
intersection_system_2 = Model2.IntersectionNetworkSimulator()
intersection_system_2.initialize(grid_dimensions=(3,3), grid_distance=250)

intersection_system_2.set_queue_rate_parameters(grid_ind=(0,0), avg_departure_time=2, avg_arrival_time_s=10, avg_arrival_time_e=10)
intersection_system_2.set_queue_rate_parameters(grid_ind=(0,1), avg_departure_time=2, avg_arrival_time_s=10)
intersection_system_2.set_queue_rate_parameters(grid_ind=(0,2), avg_departure_time=2, avg_arrival_time_s=10, avg_arrival_time_w=10)
intersection_system_2.set_queue_rate_parameters(grid_ind=(1,0), avg_departure_time=2, avg_arrival_time_e=10)
intersection_system_2.set_queue_rate_parameters(grid_ind=(1,1), avg_departure_time=2)
intersection_system_2.set_queue_rate_parameters(grid_ind=(1,2), avg_departure_time=2, avg_arrival_time_w=10)
intersection_system_2.set_queue_rate_parameters(grid_ind=(2,0), avg_departure_time=2, avg_arrival_time_n=10, avg_arrival_time_e=10)
intersection_system_2.set_queue_rate_parameters(grid_ind=(2,1), avg_departure_time=2, avg_arrival_time_n=10)
intersection_system_2.set_queue_rate_parameters(grid_ind=(2,2), avg_departure_time=2, avg_arrival_time_n=10, avg_arrival_time_w=10)

intersection_system_2.set_traffic_lights(grid_ind=(0,0), traffic_light_ns=memoryless_ns11, traffic_light_ew=memoryless_ew11)
intersection_system_2.set_traffic_lights(grid_ind=(0,1), traffic_light_ns=memoryless_ns12, traffic_light_ew=memoryless_ew12)
intersection_system_2.set_traffic_lights(grid_ind=(0,2), traffic_light_ns=memoryless_ns13, traffic_light_ew=memoryless_ew13)
intersection_system_2.set_traffic_lights(grid_ind=(1,0), traffic_light_ns=memoryless_ns21, traffic_light_ew=memoryless_ew21)
intersection_system_2.set_traffic_lights(grid_ind=(1,1), traffic_light_ns=memoryless_ns22, traffic_light_ew=memoryless_ew22)
intersection_system_2.set_traffic_lights(grid_ind=(1,2), traffic_light_ns=memoryless_ns23, traffic_light_ew=memoryless_ew23)
intersection_system_2.set_traffic_lights(grid_ind=(2,0), traffic_light_ns=memoryless_ns31, traffic_light_ew=memoryless_ew31)
intersection_system_2.set_traffic_lights(grid_ind=(2,1), traffic_light_ns=memoryless_ns32, traffic_light_ew=memoryless_ew32)
intersection_system_2.set_traffic_lights(grid_ind=(2,2), traffic_light_ns=memoryless_ns33, traffic_light_ew=memoryless_ew33)

# %%
intersection_system_2.simulate(delta_t=0.1, end_time=120, animate=True, fig_width=4, file_name="figs/simulation2_3x3.mp4", speed=3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 intersection_system_2.simulate(delta_t=0.1, end_time=120, animate=True, fig_width=4, file_name="figs/simulation2_3x3.mp4", speed=3)
#
# File ~/Python/SURF-22/BaseModel.py:699, in IntersectionNetworkSimulator.simulate(self, delta_t, end_time, fig_width, animate, file_name, speed)
#     697 with writer.saving(fig, file_name, 100):
#     698     while self.time < end_time:
# --> 699         self.run_event(delta_t=delta_t, animate=True, plt=plt)
#     700         text.set_text("Elapsed time: "+str(round(self.time,1))+"s")
#     701         writer.grab_frame()
#
# File ~/Python/SURF-22/BaseModel.py:741, in IntersectionNetworkSimulator.run_event(self, delta_t, animate, plt)
#     739 for grid_ind in self.grid_inds:
#     740     if not self.intersections[grid_ind].observable:
# ...

# %%
HTML("""
<div align="middle">
<video width="80%" controls>
      <source src="figs/simulation2_3x3.mp4" type="video/mp4">
</video></div>""")

# %%
fig, axs = intersection_system_2.plot_queue_stats(plt=plt, grid_ind=(0,1), direction='E', end_time=round(intersection_system_2.time), traffic_light=memoryless_ew12, delta_t=0.1,fig_size=(6,6))
plt.savefig('figs/3x3_eastbound_(0,1)_2', bbox_inches='tight')

# %%
stats2 = intersection_system_2.get_stats()
stats2[(0,1)]["E"]["wait_time"]

# %%
stats1 = intersection_system_1.get_stats()
stats1[(0,1)]["E"]["wait_time"]
